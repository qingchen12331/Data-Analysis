# %%
# 字符串的创建
# 单引号，双引号，三引号都可以
single_quoted='hello_world'
double_quoted="hello_world"
triple_quoted='''hello_world'''

# %%
# 字符串的连接
# 使用+号可以连接两个字符串
str1='hello'
str2='world'
connect=str1+","+str2
print(connect)
# Out:
# hello,world

# %%
# 字符串的复制
# 使用*号可以复制字符串
original_str="Python"
copied_str=original_str*3
print(copied_str)
# Out:
# PythonPythonPython

# %%
# 字符串的长度
# 使用len()函数可以获取字符串的长度
My_string="Hello,Python"
print(len(My_string))
# Out:
# 12

# %%
# 字符串索引
my_string="python"
first_char=my_string[0]
print(first_char)
# Out:
# p

# %%
# 字符串的切片
my_string="python"
substring=my_string[1:4]
print(substring)
# Out:
# yth

# %%
# 字符串的查找
my_string="hello, world"
pos=my_string.find("world")
print(pos)
# Out:
# 7

# %%
# 字符串的替换
my_string="hello, world"
new_string=my_string.replace("world",'python')
print(new_string)
# Out:
# hello, python

# %%
# 字符串大小写转换
my_stirng="hello_world"
print(my_string.upper())
# Out:
# HELLO, WORLD

# %%
# 字符串的分割与连接
# 分割用split（），连接用join（）
my_string="apple,banana,orange"
fruits=my_string.split(",")
new_string="-".join(fruits)
print(fruits,new_string)
# Out:
# ['apple', 'banana', 'orange'] apple-banana-orange

# %%
# 基本格式化
# 使用%进行基本的字符串格式化
name="Alice"
age = 25
message = "my name is %s and I am %d years old." %(name,age)
message
# Out:
# 'my name is Alice and I am 25 years old.'

# %%
# 使用f-string进行字符串格式化
name = "charlie"
age = 35
message=f"My name is {name} and I am {age} years old."
print(message)
# Out:
# My name is charlie and I am 35 years old.

# %%
# 正则表达式
import re 
pattern=re.compile(r'\b\w+\b')
text="This is a sample text."
matches=pattern.findall(text)
matches
# Out:
# ['This', 'is', 'a', 'sample', 'text']

# %%
# 字符串的匹配与替换
import re 
pattern=re.compile(r'\b\w+\b')
text="This is a sample text."
matches=pattern.sub('word',text)
matches
# Out:
# 'word word word word word.'

# %%
# 字符串的编码与解码
utf8_string="你好"
utf8_encoed=utf8_string.encode('utf-8')
decoded_string=utf8_encoded.decode('utf-8')
print(decoded_string)
# Out:
# 你好

# %%
words=["Hello","World","!"]
result=""
for word in words:
    result+=word
# 高效的拼接字符串
efficient_result="".join(words)
efficient_result
result
# Out:
# 'HelloWorld!'
