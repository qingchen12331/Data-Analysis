# %%
# 字典
person={"name":"Alice","age":30,"city":"New York"}
fruits={"apple":2,"banana":3,"cherry":1}
epty_dict={}

# %%
# 字典的键值对
# 添加键值对
person={"name":"Alice","age":30}
person["city"]="New York"
person
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
# 访问值
name=person["name"]
name
# Out:
# 'Alice'

# %%
# 修改值
person["name"]="Cherry"

# %%
person
# Out:
# {'name': 'Cherry', 'age': 30, 'city': 'New York'}

# %%
# 删除键值对
del person["name"]

# %%
person
# Out:
# {'age': 30, 'city': 'New York'}

# %%
# 检查键是否存在
contains_name="name" in person

# %%
contains_name
# Out:
# False

# %%
contain_age="age" in person
contain_age
# Out:
# True

# %%
# 获取字典长度
num=len(person)
num
# Out:
# 2

# %%
# 字典的高级操作
# 字典推导式
fruits = ["apple","banana","cherry"]
fruit_lengths = {fruit:len(fruit) for fruit in fruits}
fruit_lengths
# Out:
# {'apple': 5, 'banana': 6, 'cherry': 6}

# %%
# 获取键和值的列表
person={"name":"Alice","age":18,"sex":"男"}
key_list=list(person.keys())
value_list=list(person.values())
value_list
# Out:
# ['Alice', 18, '男']

# %%
# 嵌套字典
students = {
    "Alice" : {"age":20,"major":"computer science"},
    "Bob" : {"age":22,"major" : "Engineering"}
}

# %%
students
# Out:
# {'Alice': {'age': 20, 'major': 'computer science'},
#  'Bob': {'age': 22, 'major': 'Engineering'}}
